# %%
import psutil as ps

# %%
list(ps.process_iter())
# Out:
# [psutil.Process(pid=0, name='System Idle Process', status='running'),
#  psutil.Process(pid=4, name='System', status='running'),
#  psutil.Process(pid=172, name='Registry', status='running', started='2023-06-04 00:13:18'),
#  psutil.Process(pid=272, name='RuntimeBroker.exe', status='running', started='22:22:28'),
#  psutil.Process(pid=320, name='RuntimeBroker.exe', status='running', started='20:38:42'),
#  psutil.Process(pid=360, name='SearchProtocolHost.exe', status='running', started='22:20:32'),
#  psutil.Process(pid=648, name='smss.exe', status='running', started='2023-06-04 00:13:19'),
#  psutil.Process(pid=656, name='OpenConsole.exe', status='running', started='22:20:41'),
#  psutil.Process(pid=676, name='csrss.exe', status='running', started='2023-06-04 00:13:23'),
#  psutil.Process(pid=1160, name='wininit.exe', status='running', started='2023-06-04 00:13:26'),
#  psutil.Process(pid=1300, name='services.exe', status='running', started='2023-06-04 00:13:26'),
# ...

# %%
for x in dir(ps):
    if "_" not in x:
        print(x)
# Out:
# AIX
# AccessDenied
# BSD
# Error
# FREEBSD
# LINUX
# MACOS
# NETBSD
# NoSuchProcess
# OPENBSD
# OSX
# POSIX
# PermissionError
# Popen
# Process
# ProcessLookupError
# SUNOS
# TimeoutExpired
# WINDOWS
# ZombieProcess
# collections
# contextlib
# datetime
# functools
# getloadavg
# long
# os
# pids
# pwd
# signal
# subprocess
# sys
# test
# threading
# time
# users
